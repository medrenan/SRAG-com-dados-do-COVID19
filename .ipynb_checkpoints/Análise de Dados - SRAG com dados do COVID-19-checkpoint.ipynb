# %% [markdown]
# <b>Este trabalho foi realizado por Renan Alves de Medeiros e Nicolas Cursino Magarifuchi </b>
#
# <b>Os dados utilizados estão presntes no site https://opendatasus.saude.gov.br/dataset/bd-srag-2020</b>
#
# <b>Aviso Legal: Este notebook tem como finalidade apenas o estudo, deste modo não há garantia de qualquer tipo de precisão, confiabilidade ou atualidade das informações.
# </b>

# %%
import pandas as pd
low_memory = False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
file = r'C:\Users\renan\INFLUD-30-06-2020.csv'
df = pd.read_csv(file, delimiter=';',
                 encoding = 'ISO-8859-1',
                 error_bad_lines = False,
                 
                 # Define as colunas a serem utilizadas na análise.
                 
                 usecols=['CS_SEXO', 'NU_IDADE_N', 'CS_RACA', 'CS_ESCOL_N', 'SG_UF', 'CLASSI_FIN', 'EVOLUCAO'])

# %%
# Colunas da tabela que serão utilizadas.

for k in range(len(df.columns)):
    print (k, df.columns[k])
# Out:
# 0 CS_SEXO
# 1 NU_IDADE_N
# 2 CS_RACA
# 3 CS_ESCOL_N
# 4 SG_UF
# 5 CLASSI_FIN
# 6 EVOLUCAO

# %%
# Atribui a correspondência dos códigos de raça, escolaridade, classificação final da síndrome respiratória e evolução dos casos para seus respectivos valores.

troca_raça = {1:'Branca', 2:'Preta', 3:'Amarela',
              4:'Parda', 5:'Indígena', 9:'Ignorado'}

troca_escolaridade = {0:'Sem', 1:'Fund1', 
                      2:'Fund2', 3:'Médio',
                      4:'Superior', 
                      5:'Não se aplica',
                      9:'Ignorado'}

troca_classificação = {1:'SRAG por influenza',
                       2: 'SRAG por outro vírus respiratório',
                       3: 'SRAG por outro agente Etiológico',
                       4: 'SRAG não especificado',
                       5: 'COVID-19'}

troca_evolução = {1:'Cura', 2:'Óbito', 9:'Ignorado'}

# %%
# Aloca os valores dos dicionários dentro dos códigos das colunas de raças, escolaridade, classificação final da síndrome respiratória e evolução dos casos.

df.loc[(df.CS_RACA.isnull()), 'CS_RACA'] = 9
df['CS_RACA'] = df['CS_RACA'].apply(lambda x: troca_raça[x])

df.loc[(df.CS_ESCOL_N.isnull()), 'CS_ESCOL_N'] = 9
df['CS_ESCOL_N'] = df['CS_ESCOL_N'].apply(lambda x: troca_escolaridade[x])

df.loc[(df.CLASSI_FIN.isnull()), 'CLASSI_FIN'] = 4
df['CLASSI_FIN'] = df['CLASSI_FIN'].apply(lambda x: troca_classificação[x])

df.loc[(df.EVOLUCAO.isnull()), 'EVOLUCAO'] = 9
df['EVOLUCAO'] = df['EVOLUCAO'].apply(lambda x: troca_evolução[x])

# %%
df.sample(50).sort_values('NU_IDADE_N')
# Out:
#        CS_SEXO  NU_IDADE_N   CS_RACA     CS_ESCOL_N SG_UF  \
# 182804       F           7     Parda  Não se aplica    MS
# 126204       F          19     Parda       Ignorado    PI
# 221369       F          22    Branca       Ignorado    SP
# 8603         F          27    Branca          Médio    SC
# 124472       M          31     Parda       Ignorado    BA
# 226933       M          39    Branca          Fund2    RS
# 230843       M          41     Parda       Ignorado    SP
# 219208       F          42     Parda       Ignorado    MA
# 162853       M          43     Parda       Ignorado    CE
# 239611       F          45     Preta       Ignorado    RJ
# 280817       M          47    Branca          Médio    MG
# 338937       F          48  Ignorado       Ignorado    MG
# 28679        F          49  Ignorado       Superior    BA
# 281825       M          52    Branca          Médio    PE
# 286695       F          53  Ignorado          Fund1    SP
# 321069       F          54    Branca       Ignorado    SP
# 86751        F          55  Ignorado       Ignorado    RS
# 99069        F          56     Parda          Fund2    CE
# 181479       M          56    Branca       Ignorado    PA
# 127652       M          56    Branca          Fund1    PR
# 205143       M          58  Ignorado       Ignorado    SP
# 220795       M          59     Parda          Fund1    AM
# 330966       F          60     Parda          Fund2    RJ
# 292217       F          61  Ignorado       Ignorado    RJ
# 19484        F          61     Parda       Superior    SP
# 278399       F          62  Ignorado       Ignorado    RJ
# 54992        M          63    Branca       Ignorado    SP
# 144419       M          64     Parda       Superior    RJ
# 121410       M          66  Ignorado       Ignorado    RJ
# 215645       M          66     Parda       Ignorado    PE
# 249689       F          67  Ignorado       Ignorado    PA
# 188651       F          68    Branca       Ignorado    SP
# 207723       M          69  Ignorado       Ignorado    RJ
# 332134       M          69  Ignorado       Ignorado    MG
# 92898        M          70    Branca          Fund1    MG
# 241850       M          70     Parda          Fund1    PA
# 245746       M          70  Ignorado       Ignorado    RJ
# 300504       M          71     Parda       Ignorado    PB
# 201253       M          74  Ignorado       Ignorado    TO
# 142645       F          75     Parda       Ignorado    ES
# 315000       F          76    Branca          Fund1    PR
# 289126       M          77    Branca       Ignorado    PE
# 47747        M          80  Ignorado       Ignorado    SP
# 355265       M          80    Branca       Ignorado    SP
# 294574       F          83    Branca       Ignorado    SP
# 240702       M          85  Ignorado       Ignorado    SP
# 277031       F          86     Parda       Ignorado    MA
# 337549       F          87  Ignorado            Sem    SP
# 215271       M          90    Branca       Ignorado    SP
# 335082       F          91     Preta       Ignorado    MG
#
#                               CLASSI_FIN  EVOLUCAO
# 182804             SRAG não especificado      Cura
# 126204             SRAG não especificado  Ignorado
# 221369                          COVID-19      Cura
# 8603               SRAG não especificado      Cura
# 124472  SRAG por outro agente Etiológico     Óbito
# 226933                          COVID-19     Óbito
# 230843                          COVID-19      Cura
# 219208                          COVID-19     Óbito
# 162853             SRAG não especificado  Ignorado
# 239611             SRAG não especificado  Ignorado
# 280817                          COVID-19      Cura
# 338937             SRAG não especificado      Cura
# 28679              SRAG não especificado      Cura
# 281825             SRAG não especificado  Ignorado
# 286695                          COVID-19      Cura
# 321069                          COVID-19      Cura
# 86751              SRAG não especificado     Óbito
# 99069                           COVID-19      Cura
# 181479                          COVID-19     Óbito
# 127652             SRAG não especificado      Cura
# 205143                          COVID-19      Cura
# 220795             SRAG não especificado  Ignorado
# 330966             SRAG não especificado     Óbito
# 292217             SRAG não especificado      Cura
# 19484                           COVID-19      Cura
# 278399             SRAG não especificado  Ignorado
# 54992                           COVID-19      Cura
# 144419                          COVID-19      Cura
# 121410                          COVID-19      Cura
# 215645             SRAG não especificado  Ignorado
# 249689                          COVID-19     Óbito
# 188651             SRAG não especificado      Cura
# 207723                          COVID-19     Óbito
# 332134             SRAG não especificado  Ignorado
# 92898              SRAG não especificado  Ignorado
# 241850                          COVID-19      Cura
# 245746                          COVID-19     Óbito
# 300504             SRAG não especificado  Ignorado
# 201253             SRAG não especificado  Ignorado
# 142645                          COVID-19     Óbito
# 315000                          COVID-19  Ignorado
# 289126             SRAG não especificado     Óbito
# 47747              SRAG não especificado     Óbito
# 355265                          COVID-19  Ignorado
# 294574             SRAG não especificado  Ignorado
# 240702                          COVID-19      Cura
# 277031                          COVID-19     Óbito
# 337549             SRAG não especificado  Ignorado
# 215271                          COVID-19     Óbito
# 335082             SRAG não especificado  Ignorado

# %%
df.groupby('SG_UF').size().sort_values().tail(5).plot(kind='barh').set_title('Cinco estados com mais casos de SRAG', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Cinco estados com mais casos de SRAG')

# %%
df.query('CS_RACA != "Ignorado"').groupby('CS_RACA').size().sort_values().plot(kind='barh').set_title('Infectado SRAG por raça', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Infectado SRAG por raça')

# %%
df.groupby('CS_RACA').size().sort_values(ascending=False)

# %%
df.groupby('CS_ESCOL_N').size().sort_values(ascending=False)

# %%
df.query('EVOLUCAO == "Óbito" and CS_RACA != "Ignorado"').groupby('CS_RACA').size().plot(kind='bar').set_title('Óbito por SRAG por raça', fontsize=22)

# %%
df.query('EVOLUCAO == "Cura" and CS_RACA != "Ignorado"').groupby('CS_RACA').size().plot(kind='bar').set_title('Índice de cura de SRAG por raça', fontsize=22)

# %%
df.query('EVOLUCAO == "Óbito" and CS_ESCOL_N != "Ignorado"').groupby('CS_ESCOL_N').size().plot(kind='bar').set_title('Óbito por SRAG por nível de escolaridade', fontsize = 22)

# %%
df.query('EVOLUCAO == "Cura" and CS_ESCOL_N != "Ignorado"').groupby('CS_ESCOL_N').size().plot(kind='bar').set_title('Índice de cura de SRAG por nível de escolaridade', fontsize = 22)

# %%
df.groupby('EVOLUCAO').size().sort_values(ascending=False)

# %%
df.query('CLASSI_FIN == "COVID-19" and EVOLUCAO == "Óbito"').groupby('NU_IDADE_N').size().plot(kind='line').set_title('Óbito por COVID-19 por idade', fontsize=22)

# %%
df.query('EVOLUCAO == "Óbito"').groupby('SG_UF').size().plot(kind='bar').set_title('Óbitos por SRAG por UF', fontsize=22)

# %%
df.query('EVOLUCAO == "Óbito" and CLASSI_FIN == "COVID-19"').groupby('CS_SEXO').size().plot(kind='bar').set_title('Óbitos por COVID por sexo', fontsize=22)

# %% [markdown]
# <b> O seguinte trabalho foi utilizado como referência:</b>
#
# <b>https://github.com/fmasanori/CursoPyLadiesSP/blob/master/OpendataSUS%20SRAG%202020.ipynb</b>
#
# <b>Autor: Fernando Masanori</b>
